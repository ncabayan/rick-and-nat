# %%
import urllib
import simplejson as json

import pandas as pd                # allows use of data frame structure
import numpy as np
import datetime                    # allows me to get current timestamp
import time                        # allows me to make the program wait
 
from twitch import TwitchClient    # Twitch API library

# %%
# Specify username.19571641 is the user_id for Ninja
user_id = "19571641"

# Specify URL.
url = "https://api.twitch.tv/helix/users/follows?to_id=" + user_id

# %%
# Create URL request.
channel_id = urllib.request.Request(url)

# Add client ID and OAuth to request.
channel_id.add_header("Client-ID", 's4tqt4ku0piu2e0yayw6k08l7851qo')
channel_id.add_header("Authorization", "OAuth " + "kheftmy6d7dbzecqkmu7e7b2fc92za")

# Get info from request.
response = urllib.request.urlopen(channel_id)
json_output = json.loads(response.read())

# %%
print(json_output)
# Out:
# {'total': 13280823, 'data': [{'from_id': '118037936', 'from_name': 'alexxmagik', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2035-11-18T08:46:40Z'}, {'from_id': '244349084', 'from_name': 'D3vilGamingS', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:51:26Z'}, {'from_id': '38019673', 'from_name': 'RizzoRules', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:51:20Z'}, {'from_id': '414398138', 'from_name': 'ttvpreiumstage', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:51:18Z'}, {'from_id': '402070924', 'from_name': 'nicolo006', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:51:14Z'}, {'from_id': '414284810', 'from_name': 'dtr_skyset', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:51:10Z'}, {'from_id': '188767159', 'from_name': 'mad_dayz', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:50:59Z'}, {'from_id': '409733640', 'from_name': 'xhoelin07', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:50:55Z'}, {'from_id': '414445139', 'from_name': 'bumfreckle1000', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:50:47Z'}, {'from_id': '263233851', 'from_name': 'chlodzik3', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:50:41Z'}, {'from_id': '411727555', 'from_name': 'abdelrahmanyt59', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:50:12Z'}, {'from_id': '402090817', 'from_name': 'ttvshank', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:50:07Z'}, {'from_id': '414416775', 'from_name': 'kikae17', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:50:02Z'}, {'from_id': '266153835', 'from_name': 'pacxgaming_', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:49:53Z'}, {'from_id': '413199844', 'from_name': 'animebexx', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:49:52Z'}, {'from_id': '414445295', 'from_name': 'xxdontpanlcxx', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:49:44Z'}, {'from_id': '411253517', 'from_name': 'wickham0610', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:49:42Z'}, {'from_id': '414270037', 'from_name': 'spidy421421', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:49:42Z'}, {'from_id': '414444666', 'from_name': 'meupirutadoce_', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:49:38Z'}, {'from_id': '272416035', 'from_name': 'fhidan77', 'to_id': '19571641', 'to_name': 'Ninja', 'followed_at': '2019-02-04T19:49:33Z'}], 'pagination': {'cursor': 'eyJiIjpudWxsLCJhIjp7IkN1cnNvciI6IjE1NDkzMDk3NzMyMzcxNzM3MzQifX0'}}

# %%
print(json.dumps(json_output, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "followed_at": "2035-11-18T08:46:40Z",
#             "from_id": "118037936",
#             "from_name": "alexxmagik",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:51:26Z",
#             "from_id": "244349084",
#             "from_name": "D3vilGamingS",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:51:20Z",
#             "from_id": "38019673",
#             "from_name": "RizzoRules",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:51:18Z",
#             "from_id": "414398138",
#             "from_name": "ttvpreiumstage",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:51:14Z",
#             "from_id": "402070924",
#             "from_name": "nicolo006",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:51:10Z",
#             "from_id": "414284810",
#             "from_name": "dtr_skyset",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:50:59Z",
#             "from_id": "188767159",
#             "from_name": "mad_dayz",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:50:55Z",
#             "from_id": "409733640",
#             "from_name": "xhoelin07",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:50:47Z",
#             "from_id": "414445139",
#             "from_name": "bumfreckle1000",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:50:41Z",
#             "from_id": "263233851",
#             "from_name": "chlodzik3",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:50:12Z",
#             "from_id": "411727555",
#             "from_name": "abdelrahmanyt59",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:50:07Z",
#             "from_id": "402090817",
#             "from_name": "ttvshank",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:50:02Z",
#             "from_id": "414416775",
#             "from_name": "kikae17",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:49:53Z",
#             "from_id": "266153835",
#             "from_name": "pacxgaming_",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:49:52Z",
#             "from_id": "413199844",
#             "from_name": "animebexx",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:49:44Z",
#             "from_id": "414445295",
#             "from_name": "xxdontpanlcxx",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:49:42Z",
#             "from_id": "411253517",
#             "from_name": "wickham0610",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:49:42Z",
#             "from_id": "414270037",
#             "from_name": "spidy421421",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:49:38Z",
#             "from_id": "414444666",
#             "from_name": "meupirutadoce_",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         },
#         {
#             "followed_at": "2019-02-04T19:49:33Z",
#             "from_id": "272416035",
#             "from_name": "fhidan77",
#             "to_id": "19571641",
#             "to_name": "Ninja"
#         }
#     ],
#     "pagination": {
#         "cursor": "eyJiIjpudWxsLCJhIjp7IkN1cnNvciI6IjE1NDkzMDk3NzMyMzcxNzM3MzQifX0"
#     },
#     "total": 13280823
# }

# %%
follower_count = json_output['total']

# %%
print(follower_count)
# Out:
# 13280823

# %%
# Create empty data frame.
results = pd.DataFrame(columns = ['time', 'follower_count'])

# Start loop
for i in range(24):
    
    # Print progress
    print('')
    print('Iteration:', i + 1)
    print('')
    
    # Get total views data
    
    # Create client.
    client = TwitchClient(client_id = 's4tqt4ku0piu2e0yayw6k08l7851qo')

    # Get channel.
    channel = client.channels.get_by_id(user_id)
    
    # Get follower count data
    
    # Specify URL.
    follower_url = "https://api.twitch.tv/helix/users/follows?to_id=" + user_id
    
    # Create URL request.
    channel_id = urllib.request.Request(follower_url)
    
    # Add client ID and OAuth to request.
    channel_id.add_header("Client-ID", 's4tqt4ku0piu2e0yayw6k08l7851qo')
    channel_id.add_header("Authorization", "OAuth " + "kheftmy6d7dbzecqkmu7e7b2fc92za")
    
    # Get data.
    response = urllib.request.urlopen(channel_id)
    json_output = json.loads(response.read())
    
    # "json_output" will only have info if a live stream is going on!
    #if len(json_output['data']) == 0:
        #stream_viewers = np.nan
   # else:
        #stream_viewers = json_output['data'][0]['viewer_count']
    
    # telling where follower count is 
    follower_count = json_output['total']
    
    
    # Generate new row to add to "results"
    to_add = pd.DataFrame({'time': [datetime.datetime.now()], 
                           'follower_count': follower_count})
    
    # Add new row to "results".
    results = results.append(to_add)
    del(to_add)
    
    # Export CSV
    results.to_csv("ninja_follower_count.csv")
    
    # Wait before next loop iteration
    #time.sleep(60 * 60)                 # Wait one hour
    time.sleep(3600)
