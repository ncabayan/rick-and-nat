# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('/Users/rserio/Desktop/YTGlobal.csv')
data
# Out:
#      Video Length  Likes  Dislikes  Comments  Shares  Total Engagements  \
# 0             552   1345        29        80     293               1747
# 1             151    522        11        30      76                639
# 2             482    484        20        48      55                607
# 3             173    854        12        47     216               1129
# 4             144    786        15        54     104                959
# 5             140    687        28        34      62                811
# 6             545   1353        56        97     224               1730
# 7             190    887        21        57     140               1105
# 8             593    748        28        50     197               1023
# 9             927    952        36        82     234               1304
# 10             59      0         0         0       3                  3
# 11            186    628        13        41     124                806
# ...

# %%
# Varriable list

# %%
y = data['Subs Gained']
x1 =data['Shares']
x2 =data['Total Views 7 days after published']
x3 =data['Total Minutes Watched 7 days after published']
x4 =data['Total Ad Views View 28']
x5 =data['Total Completed Views']
x6 =data['Comments']

# %%
# X1 is Shares

# %%
plt.scatter(x1,y,color='C0')
plt.xlabel('Shares', fontsize=20)
plt.ylabel('Subs Gained',fontsize =20)
plt.show()

# %%
# X2 is Total Views V-7

# %%
plt.scatter(x2,y,color='C0')
plt.xlabel('Total Views 7 days after published', fontsize=20)
plt.ylabel('Subs Gained',fontsize =20)
plt.show()

# %%
# X3 is Total Mins Watched V-7

# %%
plt.scatter(x3,y,color='C0')
plt.xlabel('Total Minutes Watched 7 days after published', fontsize=20)
plt.ylabel('Subs Gained',fontsize =20)
plt.show()

# %%
# X4 is Total Ad Views V-28

# %%
plt.scatter(x4,y,color='C0')
plt.xlabel('Total Ad Views View 28', fontsize=20)
plt.ylabel('Subs Gained',fontsize =20)
plt.show()

# %%
# X5 is Total Completed Views

# %%
plt.scatter(x5,y,color='C0')
plt.xlabel('Total Completed Views', fontsize=20)
plt.ylabel('Subs Gained',fontsize =20)
plt.show()

# %%
# X6 is Comments

# %%
plt.scatter(x6,y,color='C0')
plt.xlabel('Comments', fontsize=20)
plt.ylabel('Subs Gained',fontsize =20)
plt.show()
